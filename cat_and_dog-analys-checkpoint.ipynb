# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle
import time

# %%
DIRECTORY= r'C:\Jupyter_notebook\cat_dog-img-classifier\cat-dog_data\train'
CATEGORIES=['cats','dogs']

# %%
IMG_SIZE= 100
data =[]

for category in CATEGORIES:
    folder = os.path.join(DIRECTORY,category)
    label= CATEGORIES.index(category)
    for img in os.listdir(folder):
        img_path = os.path.join(folder,img)
        img_arr = cv2.imread(img_path)
        img_arr = cv2.resize(img_arr,(IMG_SIZE,IMG_SIZE))
        data.append([img_arr,label])

# %%
len(data)
# Out:
# 16

# %%
random.shuffle(data)

# %%
x=[]
y=[]
for features,labels in data:
    x.append(features)
    y.append(labels)

# %%
x=np.array(x)
y=np.array(y)

# %%
len(y)
# Out:
# 16

# %%
pickle.dump(x,open('x.pkl','wb'))
pickle.dump(y,open('y.pkl','wb'))

# %%
x=pickle.load(open('x.pkl','rb'))
y=pickle.load(open('y.pkl','rb'))

# %%
X=x/255

# %%
X
# Out:
# array([[[[0.1254902 , 0.14509804, 0.16470588],
#          [0.12156863, 0.14901961, 0.16078431],
#          [0.29019608, 0.33333333, 0.33333333],
#          ...,
#          [0.38431373, 0.41176471, 0.63529412],
#          [0.41176471, 0.43921569, 0.65098039],
#          [0.31764706, 0.35686275, 0.54901961]],
#
#         [[0.43137255, 0.43921569, 0.45882353],
#          [0.29019608, 0.29411765, 0.31764706],
#          [0.24313725, 0.25882353, 0.27058824],
#          ...,
#          [0.41960784, 0.43921569, 0.66666667],
#          [0.44705882, 0.46666667, 0.68235294],
#          [0.32941176, 0.35686275, 0.55294118]],
#
#         [[0.46666667, 0.45098039, 0.49411765],
#          [0.40784314, 0.39607843, 0.43137255],
#          [0.4       , 0.4       , 0.42352941],
#          ...,
#          [0.44705882, 0.45490196, 0.68235294],
#          [0.47058824, 0.48627451, 0.70196078],
#          [0.39607843, 0.41176471, 0.61176471]],
#
#         ...,
#
#         [[0.84313725, 0.8627451 , 0.85882353],
#          [0.92156863, 0.92941176, 0.92941176],
#          [0.92941176, 0.92941176, 0.92941176],
#          ...,
#          [0.86666667, 0.85490196, 0.8627451 ],
#          [0.87058824, 0.85882353, 0.86666667],
#          [0.8627451 , 0.85098039, 0.85882353]],
#
#         [[0.81176471, 0.83137255, 0.82745098],
#          [0.91764706, 0.9254902 , 0.9254902 ],
#          [0.92941176, 0.92941176, 0.92941176],
#          ...,
#          [0.85882353, 0.84705882, 0.85490196],
#          [0.85098039, 0.83921569, 0.84705882],
#          [0.83921569, 0.82745098, 0.83529412]],
#
#         [[0.78823529, 0.80784314, 0.80392157],
#          [0.90980392, 0.91764706, 0.91764706],
#          [0.88627451, 0.88627451, 0.88627451],
#          ...,
#          [0.84313725, 0.83137255, 0.83921569],
#          [0.84313725, 0.83137255, 0.83921569],
#          [0.85098039, 0.83921569, 0.84705882]]],
#
#
#        [[[0.42745098, 0.43921569, 0.16078431],
#          [0.43529412, 0.45490196, 0.16078431],
#          [0.45098039, 0.47058824, 0.16862745],
#          ...,
#          [0.47058824, 0.49019608, 0.17647059],
#          [0.45490196, 0.47058824, 0.17254902],
#          [0.45882353, 0.47058824, 0.18431373]],
#
#         [[0.43921569, 0.45490196, 0.16470588],
#          [0.45098039, 0.47058824, 0.17254902],
#          [0.4627451 , 0.48627451, 0.17647059],
#          ...,
#          [0.47843137, 0.50196078, 0.18823529],
#          [0.47058824, 0.48627451, 0.18431373],
#          [0.45490196, 0.47058824, 0.17647059]],
#
#         [[0.44705882, 0.47058824, 0.16862745],
#          [0.4627451 , 0.48627451, 0.17647059],
#          [0.4745098 , 0.50196078, 0.18431373],
#          ...,
#          [0.47843137, 0.50196078, 0.18039216],
#          [0.48235294, 0.50196078, 0.19215686],
#          [0.4745098 , 0.49019608, 0.18823529]],
#
#         ...,
#
#         [[0.34901961, 0.36078431, 0.14117647],
#          [0.34901961, 0.36078431, 0.14117647],
#          [0.36078431, 0.37254902, 0.15294118],
#          ...,
#          [0.22352941, 0.23921569, 0.04705882],
#          [0.22352941, 0.23921569, 0.04705882],
#          [0.22745098, 0.24313725, 0.05098039]],
#
#         [[0.3254902 , 0.32941176, 0.13333333],
#          [0.34901961, 0.35686275, 0.15686275],
#          [0.34509804, 0.35686275, 0.14117647],
#          ...,
#          [0.21568627, 0.24313725, 0.05882353],
#          [0.21176471, 0.23921569, 0.05490196],
#          [0.20392157, 0.22352941, 0.0627451 ]],
#
#         [[0.31764706, 0.31764706, 0.12941176],
#          [0.33333333, 0.3372549 , 0.14117647],
#          [0.32941176, 0.34117647, 0.1254902 ],
#          ...,
#          [0.19607843, 0.22745098, 0.04313725],
#          [0.19607843, 0.22745098, 0.04313725],
#          [0.19215686, 0.21176471, 0.05490196]]],
#
#
#        [[[0.59215686, 0.70980392, 0.82745098],
#          [0.60392157, 0.72156863, 0.82352941],
#          [0.63921569, 0.76078431, 0.82745098],
#          ...,
#          [0.98039216, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [1.        , 1.        , 1.        ]],
#
#         [[0.65882353, 0.77647059, 0.83921569],
#          [0.69803922, 0.80392157, 0.87843137],
#          [0.72156863, 0.83529412, 0.8745098 ],
#          ...,
#          [0.98431373, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [1.        , 1.        , 1.        ]],
#
#         [[0.69019608, 0.80392157, 0.82352941],
#          [0.73333333, 0.82352941, 0.89411765],
#          [0.75686275, 0.83921569, 0.89019608],
#          ...,
#          [0.98039216, 1.        , 0.99607843],
#          [0.99215686, 1.        , 1.        ],
#          [1.        , 1.        , 1.        ]],
#
#         ...,
#
#         [[0.63529412, 0.62745098, 0.62745098],
#          [0.6627451 , 0.65490196, 0.65490196],
#          [0.65098039, 0.64313725, 0.64313725],
#          ...,
#          [0.67843137, 0.63921569, 0.61176471],
#          [0.67058824, 0.63137255, 0.60392157],
#          [0.69019608, 0.65098039, 0.62352941]],
#
#         [[0.64705882, 0.63921569, 0.63921569],
#          [0.64313725, 0.63529412, 0.63529412],
#          [0.64313725, 0.63529412, 0.63529412],
#          ...,
#          [0.67843137, 0.63921569, 0.61568627],
#          [0.68235294, 0.64313725, 0.61568627],
#          [0.67843137, 0.63921569, 0.61176471]],
#
#         [[0.64313725, 0.63137255, 0.63137255],
#          [0.63137255, 0.61568627, 0.61568627],
#          [0.63921569, 0.62745098, 0.62745098],
#          ...,
#          [0.69019608, 0.65098039, 0.62352941],
#          [0.69411765, 0.65490196, 0.62745098],
#          [0.70980392, 0.67058824, 0.64313725]]],
#
#
#        ...,
#
#
#        [[[0.66666667, 0.6745098 , 0.61960784],
#          [0.6627451 , 0.66666667, 0.60392157],
#          [0.64705882, 0.63921569, 0.56470588],
#          ...,
#          [0.32156863, 0.34901961, 0.37647059],
#          [0.2745098 , 0.34117647, 0.32941176],
#          [0.30588235, 0.50980392, 0.45882353]],
#
#         [[0.6745098 , 0.68235294, 0.63529412],
#          [0.6627451 , 0.6627451 , 0.60784314],
#          [0.64313725, 0.63529412, 0.56470588],
#          ...,
#          [0.32941176, 0.36078431, 0.38823529],
#          [0.25098039, 0.33333333, 0.32156863],
#          [0.3254902 , 0.51372549, 0.46666667]],
#
#         [[0.69411765, 0.69803922, 0.6627451 ],
#          [0.66666667, 0.6627451 , 0.62352941],
#          [0.66666667, 0.65490196, 0.6       ],
#          ...,
#          [0.31764706, 0.36078431, 0.38431373],
#          [0.25098039, 0.36470588, 0.34509804],
#          [0.3254902 , 0.52156863, 0.4745098 ]],
#
#         ...,
#
#         [[0.65882353, 0.78823529, 0.89019608],
#          [0.64705882, 0.79215686, 0.89411765],
#          [0.62352941, 0.72941176, 0.83529412],
#          ...,
#          [0.43529412, 0.63921569, 0.63921569],
#          [0.41960784, 0.62745098, 0.62745098],
#          [0.41960784, 0.62745098, 0.61568627]],
#
#         [[0.64705882, 0.76078431, 0.88235294],
#          [0.65490196, 0.78039216, 0.89019608],
#          [0.60784314, 0.69411765, 0.8       ],
#          ...,
#          [0.43137255, 0.64313725, 0.64705882],
#          [0.4       , 0.60392157, 0.61568627],
#          [0.41960784, 0.63137255, 0.63137255]],
#
#         [[0.64705882, 0.76078431, 0.88235294],
#          [0.65490196, 0.78039216, 0.89411765],
#          [0.6627451 , 0.7372549 , 0.84313725],
#          ...,
#          [0.43137255, 0.64313725, 0.65098039],
#          [0.38823529, 0.59215686, 0.61568627],
#          [0.38431373, 0.59215686, 0.60392157]]],
#
#
#        [[[0.36862745, 0.51764706, 0.66666667],
#          [0.54117647, 0.6745098 , 0.81568627],
#          [0.58823529, 0.69803922, 0.83529412],
#          ...,
#          [0.99215686, 0.79607843, 0.65490196],
#          [0.99215686, 0.79607843, 0.65490196],
#          [0.99215686, 0.79607843, 0.65490196]],
#
#         [[0.61176471, 0.76862745, 0.93333333],
#          [0.42745098, 0.56470588, 0.72156863],
#          [0.36470588, 0.47843137, 0.62352941],
#          ...,
#          [0.99215686, 0.79607843, 0.65490196],
#          [0.99215686, 0.79607843, 0.65490196],
#          [0.99215686, 0.79607843, 0.65490196]],
#
#         [[0.45882353, 0.62352941, 0.8       ],
#          [0.5254902 , 0.6745098 , 0.84313725],
#          [0.34901961, 0.47058824, 0.63137255],
#          ...,
#          [1.        , 0.80392157, 0.6627451 ],
#          [1.        , 0.80392157, 0.6627451 ],
#          [1.        , 0.80392157, 0.6627451 ]],
#
#         ...,
#
#         [[0.1372549 , 0.20784314, 0.23529412],
#          [0.24313725, 0.29019608, 0.32941176],
#          [0.44705882, 0.51372549, 0.56470588],
#          ...,
#          [0.4627451 , 0.54117647, 0.58431373],
#          [0.39607843, 0.49411765, 0.53333333],
#          [0.48627451, 0.54509804, 0.59215686]],
#
#         [[0.35294118, 0.40392157, 0.41568627],
#          [0.38431373, 0.45882353, 0.47843137],
#          [0.40784314, 0.48235294, 0.51372549],
#          ...,
#          [0.01176471, 0.07843137, 0.1372549 ],
#          [0.28235294, 0.33333333, 0.39607843],
#          [0.52156863, 0.56078431, 0.62745098]],
#
#         [[0.80784314, 0.84705882, 0.88627451],
#          [0.62352941, 0.6627451 , 0.70196078],
#          [0.58431373, 0.62352941, 0.6627451 ],
#          ...,
#          [0.31764706, 0.38039216, 0.42745098],
#          [0.22745098, 0.25490196, 0.31764706],
#          [0.34901961, 0.4       , 0.47058824]]],
#
#
#        [[[0.85098039, 0.81960784, 0.82352941],
#          [0.82352941, 0.79215686, 0.79607843],
#          [0.85882353, 0.82745098, 0.83137255],
#          ...,
#          [0.91372549, 0.89019608, 0.89411765],
#          [0.91372549, 0.89019608, 0.89411765],
#          [0.90980392, 0.89411765, 0.89019608]],
#
#         [[0.85098039, 0.81960784, 0.82352941],
#          [0.82352941, 0.79215686, 0.79607843],
#          [0.87058824, 0.83921569, 0.84313725],
#          ...,
#          [0.91372549, 0.89019608, 0.89411765],
#          [0.91372549, 0.89019608, 0.89411765],
#          [0.90980392, 0.89411765, 0.89019608]],
#
#         [[0.85098039, 0.81960784, 0.82352941],
#          [0.84313725, 0.81176471, 0.81568627],
#          [0.86666667, 0.83529412, 0.83921569],
#          ...,
#          [0.91372549, 0.89019608, 0.89411765],
#          [0.91372549, 0.89019608, 0.89411765],
#          [0.91372549, 0.89411765, 0.89019608]],
#
#         ...,
#
#         [[0.29411765, 0.25882353, 0.29803922],
#          [0.24313725, 0.22745098, 0.2627451 ],
#          [0.35686275, 0.36470588, 0.39607843],
#          ...,
#          [0.78823529, 0.76470588, 0.78431373],
#          [0.79607843, 0.77647059, 0.78431373],
#          [0.80392157, 0.78039216, 0.8       ]],
#
#         [[0.29803922, 0.29803922, 0.3372549 ],
#          [0.30196078, 0.29019608, 0.3254902 ],
#          [0.37254902, 0.35294118, 0.37254902],
#          ...,
#          [0.45490196, 0.49411765, 0.53333333],
#          [0.45882353, 0.49411765, 0.53333333],
#          [0.4745098 , 0.49411765, 0.5372549 ]],
#
#         [[0.23137255, 0.23529412, 0.2745098 ],
#          [0.35294118, 0.34117647, 0.37647059],
#          [0.30980392, 0.28627451, 0.30588235],
#          ...,
#          [0.50196078, 0.54117647, 0.58039216],
#          [0.48627451, 0.5254902 , 0.56470588],
#          [0.50588235, 0.52941176, 0.57254902]]]])

# %%
X.shape
# Out:
# (16, 100, 100, 3)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model= Sequential()

model.add(Conv2D(64,(3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64,(3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(128, input_shape=X.shape[1:],activation='relu'))

model.add(Dense(2,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
model.fit(X,y,epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1/1 [==============================] - 2s 2s/step - loss: 0.6932 - accuracy: 0.6429 - val_loss: 9.5329 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 1/1 [==============================] - 0s 194ms/step - loss: 2.9785 - accuracy: 0.5714 - val_loss: 0.1574 - val_accuracy: 1.0000
# Epoch 3/5
# 1/1 [==============================] - 0s 197ms/step - loss: 0.5801 - accuracy: 0.5714 - val_loss: 0.4588 - val_accuracy: 1.0000
# Epoch 4/5
# 1/1 [==============================] - 0s 183ms/step - loss: 0.4078 - accuracy: 0.8571 - val_loss: 1.0813 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 1/1 [==============================] - 0s 186ms/step - loss: 0.3397 - accuracy: 0.8571 - val_loss: 0.8639 - val_accuracy: 0.0000e+00
